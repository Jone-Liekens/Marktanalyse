# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:postgres@localhost:5432/databasename")
connection = engine.connect()

# %%
df = pd.read_sql_query("SELECT * FROM rfq_request_details", con = engine)

# %%
lege_waarden_per_kolom = df.apply(lambda col: col.isnull().sum() + (col.astype(str).str.strip() == "").sum())

# Totaal aantal lege waarden in het hele dataframe
totaal_lege_waarden = lege_waarden_per_kolom.sum()

print(f"Totaal aantal lege waarden (NaN + lege strings): {totaal_lege_waarden}")
print("\nLege waarden per kolom:")
print(lege_waarden_per_kolom)
# Out:
# Totaal aantal lege waarden (NaN + lege strings): 160067
#
# Lege waarden per kolom:
# id                                 0
# response_deadline                  2
# status                             0
# description                        0
# technical_context              21525
# business_context                3607
# hours_to_be_worked              6340
# days_per_person                 3390
# min_days                       21275
# max_days                       21277
# customer_reference              6685
# candidate_weighting             6897
# additional_job_info            10691
# full_submission_required       21525
# required_for_each_candidate    20447
# remote_work_possible           16406
# dtype: int64

# %%
for name in df.columns:
    unieke_waarden = df[name].value_counts()

    # Print de unieke waarden
    print(unieke_waarden)
    print('\n' * 10)
# Out:
# id
# 1        1
# 14178    1
# 14185    1
# 14184    1
# 14183    1
#         ..
# 7008     1
# 7007     1
# 7006     1
# 7005     1
# 21529    1
# Name: count, Length: 21525, dtype: int64
#
#
#
#
#
#
#
#
#
#
#
# response_deadline
# 2020-09-04    308
# 2022-11-25     71
# 2020-12-04     49
# 2023-11-28     47
# 2018-09-28     42
#              ...
# 2025-01-05      1
# 2016-05-28      1
# 2022-11-27      1
# 2025-01-06      1
# 2022-07-21      1
# Name: count, Length: 3053, dtype: int64
#
#
#
#
#
#
#
#
#
#
#
# status
# Afgesloten                                 17615
# Geannuleerd                                 3317
# Gepubliceerd                                 447
# On hold                                       35
# Afgesloten - Totaal : 9 Voorstel(len)          7
#                                            ...
# Geannuleerd - Totaal : 24 Voorstel(len)        1
# Afgesloten - Totaal : 59 Voorstel(len)         1
# Afgesloten - Totaal : 1 Voorstel(len)          1
# ...
