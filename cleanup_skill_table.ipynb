# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

engine = create_engine("postgresql://postgres:postgres@localhost:5432/databasename")
connection = engine.connect()

requests = "rfq_request"
details = "rfq_request_detail"
profiles = "rfq_consultant_profile"
skills = "rfq_consultant_skill"

# %%
 
df = pd.read_sql_query("SELECT * FROM " + skills, con = engine)
print(df.head())
# Out:
#    id                                         skill             requested  \
# 0   1      Aantoonbare ervaring met GeoTools en JTS                    Ja
# 1   2                 Aantoonbare ervaring met Java  Expert ( 8,00 jaar )
# 2   3           Aantoonbare ervaring met Javascript  Expert ( 8,00 jaar )
# 3   4         Aantoonbare ervaring met Spring(Boot)  Senior ( 5,00 jaar )
# 4   5  Aantoonbare ervaring als technisch architect  Senior ( 5,00 jaar )
#
#         weight                        answer_type skill_type  profile_id
# 0    Must have                          Ja / Neen   SPECIFIC           1
# 1    Must have  Ervaringsniveaus en jaar ervaring   SPECIFIC           1
# 2    Must have  Ervaringsniveaus en jaar ervaring   SPECIFIC           1
# 3    Must have  Ervaringsniveaus en jaar ervaring   SPECIFIC           1
# 4  Should have  Ervaringsniveaus en jaar ervaring   SPECIFIC           1

# %%
print(set(df["weight"].values))

df["weight"] = df["weight"].fillna("None")

weights = df["weight"].values

unique, counts = np.unique(weights, return_counts=True)

counts = dict(zip(unique, counts))
for x in counts:
    print(x, counts[x])
# Out:
# {'7', '', '5', '10', None, 'Must have', 'Nice to have', '1', '8', 'Should have', '9'}
#  5446
# 1 3
# 10 8
# 5 7
# 7 4
# 8 4
# 9 1
# Must have 82717
# Nice to have 38982
# None 137454
# Should have 35073

# %%
column = "requested"

df[column] = df[column].fillna("None")

weights = df[column].values

unique, counts = np.unique(weights, return_counts=True)

counts = dict(zip(unique, counts))
for x in counts:
    print(x, " -> ", counts[x])
# Out:
#  1710
#  href="index.php?event=general.document&amp;id=6755b45f9c1d8&amp;pageContext=&amp;requestNr=11" target="_blank">IT-Code AG Digipolis Antwerpen.pdf</a> 1
#  href="index.php?event=general.document&amp;id=6755b45f9ca7a&amp;pageContext=&amp;requestNr=11" target="_blank">NDA_AG Digipolis Antwerpen.docx</a> 1
#  href="index.php?event=general.document&amp;id=6755b7a2558a0&amp;pageContext=&amp;requestNr=16" target="_blank">Extra motivatie.docx</a> 1
#  href="index.php?event=general.document&amp;id=6755b7e744e8f&amp;pageContext=&amp;requestNr=41" target="_blank">IT-Code AG Digipolis Antwerpen.pdf</a> 1
#  href="index.php?event=general.document&amp;id=6755b7e7457f8&amp;pageContext=&amp;requestNr=41" target="_blank">NDA_AG Digipolis Antwerpen.docx</a> 1
#  href="index.php?event=general.document&amp;id=6755b859eb56a&amp;pageContext=&amp;requestNr=78" target="_blank">Bijkomende vragenlijst bij FLU003458.docx</a> 1
# ...
